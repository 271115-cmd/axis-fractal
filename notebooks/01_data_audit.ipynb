# %% [markdown]
# # 01 — Data Audit  (Phase 1)
#
# Interactive exploration of OSM coverage: street-segment density and building-footprint counts per 500 m tile, quick-look maps, and a visual check of 3 known hutong tiles against satellite imagery.
#
# **To be filled in during Phase 1.** Imports the pipeline modules from `../src/`.

# %%
# Phase 1 work goes here.
import sys
sys.path.append('../src')
