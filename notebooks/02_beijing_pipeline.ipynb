# %% [markdown]
# # 02 — Beijing Pipeline  (Phases 2–5)
#
# End-to-end run for the three Beijing transects: rasterize → box-counting dimension → gliding-box lacunarity → per-tile sampling and zone statistics.
#
# **To be filled in during Phases 2–5.**

# %%
import sys
sys.path.append('../src')
