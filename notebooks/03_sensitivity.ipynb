# %% [markdown]
# # 03 — Sensitivity Analysis  (Phase 6)
#
# Re-run the pipeline while varying raster resolution (1/2/4 m), street buffer widths (±50%), and representation (streets vs footprints). Does the zone ranking hold? This section is as important as the main result.
#
# **To be filled in during Phase 6.**

# %%
import sys
sys.path.append('../src')
