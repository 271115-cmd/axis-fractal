# %% [markdown]
# # 04 — Hong Kong Comparison  (Phase 8)
#
# Hong Kong has **no imperial ceremonial axis** — which is exactly why it is a powerful stress-test of the Beijing hypothesis: is human-scale texture a product of *heritage protection* or of *morphology*?
#
# Same pipeline, new bounding boxes + CRS (Hong Kong 1980 Grid, EPSG:2326). Four sample zones:
# 1. **Sham Shui Po / Mong Kok** — fine-grain *tong lau* street fabric (fine-grain hyper-modernity)
# 2. **Podium-tower megastructure** — Union Square / Kowloon Station, Central reclamation, or Tseung Kwan O (the extreme high-lacunarity case)
# 3. **New Territories walled village** — e.g. Kat Hing Wai (Chinese-vernacular heritage, courtyard-logic cousin of the siheyuan)
# 4. *(optional)* **Wan Chai** — a mixed transitional zone
#
# Notes: HK OSM building-footprint coverage is generally strong — prefer the footprint representation here, and use this arm to cross-validate the street-vs-footprint sensitivity from Phase 6. **Stated limitation:** this is 2D plan analysis; Hong Kong's verticality is not captured.
#
# **To be filled in during Phase 8.** Reuses every module in `../src/`.

# %%
import sys
sys.path.append('../src')
